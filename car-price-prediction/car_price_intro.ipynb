# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: object

# %%
df.columns=df.columns.str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
strings = list(df.dtypes [df.dtypes == object].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for val in strings:
    df[val]=df[val].str.lower().str.replace(" ","_")

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:6])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler' 'nissan']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class' '2_series']
# 914
#
# year
# [2011 2012 2013 1992 1993 1994]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel'
#  'electric']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172. 160.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.  0.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance' 'flex_fuel']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp<100000],bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
prices_logs = np.log1p(df.msrp)

# %%
sns.histplot(prices_logs,bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %% [markdown]
# Setting up validation framework

# %%
n = len(df)

# %%
n_val = int(n*0.2)
n_test = int(n*0.2)
n_train =n- n_val - n_test

# %%
n,n_val,n_test ,n_train
# Out:
# (11914, 2382, 2382, 7150)

# %%
df.iloc[[10,0,3,5]]
# Out:
#    make       model  year             engine_fuel_type  engine_hp  \
# 10  bmw    1_series  2013  premium_unleaded_(required)      300.0
# 0   bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 3   bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5   bmw    1_series  2012  premium_unleaded_(required)      230.0
#
#     engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 10               6.0            manual  rear_wheel_drive              2.0
# 0                6.0            manual  rear_wheel_drive              2.0
# 3                6.0            manual  rear_wheel_drive              2.0
# 5                6.0            manual  rear_wheel_drive              2.0
#
#                           market_category vehicle_size vehicle_style  \
# 10                luxury,high-performance      compact         coupe
# 0   factory_tuner,luxury,high-performance      compact         coupe
# ...

# %%
df_train = df.iloc[n_train:]
df_val = df.iloc[n_train:n_train+n_val]
df_test = df.iloc[n_train+n_val: ]

# %%
idx = np.arange(n)
idx
# Out:
# array([    0,     1,     2, ..., 11911, 11912, 11913], shape=(11914,))

# %%
np.random.seed(2)
np.random.shuffle(idx)
idx
df.iloc[idx[n_train:]]
# Out:
#                 make               model  year  \
# 2779       chevrolet            colorado  2015
# 3708   mercedes-benz             e-class  2017
# 4794            ford               focus  2017
# 10498          acura                 tlx  2016
# 1880      volkswagen  beetle_convertible  2016
# ...              ...                 ...   ...
# 2514       chevrolet           chevy_van  1998
# 11798         subaru        xv_crosstrek  2014
# 6637           dodge              magnum  2006
# 2575           honda               civic  2016
# 7336          subaru             outback  2015
#
#                      engine_fuel_type  engine_hp  engine_cylinders  \
# 2779                 regular_unleaded      200.0               4.0
# 3708      premium_unleaded_(required)      241.0               4.0
# 4794         flex-fuel_(unleaded/e85)      160.0               4.0
# 10498  premium_unleaded_(recommended)      290.0               6.0
# ...

# %%
df.iloc[idx[:10]]
# Out:
#              make            model  year             engine_fuel_type  \
# 2735    chevrolet           cobalt  2008             regular_unleaded
# 6720       toyota           matrix  2012             regular_unleaded
# 5878       subaru          impreza  2016             regular_unleaded
# 11190  volkswagen          vanagon  1991             regular_unleaded
# 4554         ford            f-150  2017     flex-fuel_(unleaded/e85)
# 8001   volkswagen           rabbit  2008             regular_unleaded
# 2882      bentley  continental_gtc  2013  premium_unleaded_(required)
# 649           bmw         6_series  2015  premium_unleaded_(required)
# 616       maybach               57  2012  premium_unleaded_(required)
# 4459         ford   f-150_heritage  2004             regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            manual  front_wheel_drive
# ...

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:] ]

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     chevrolet       cobalt  2008                regular_unleaded
# 6720        toyota       matrix  2012                regular_unleaded
# 5878        subaru      impreza  2016                regular_unleaded
# 11190   volkswagen      vanagon  1991                regular_unleaded
# 4554          ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...            ...          ...   ...                             ...
# 434            bmw     4_series  2015     premium_unleaded_(required)
# 1902    volkswagen       beetle  2015  premium_unleaded_(recommended)
# 9334           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 5284   rolls-royce        ghost  2014     premium_unleaded_(required)
# 2420    volkswagen           cc  2017  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
len(df_train)
# Out:
# 7150

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
del df_train['msrp']
del df_test['msrp']
del df_val['msrp']

# %%
len(y_train)
# Out:
# 7150

# %% [markdown]
# linear regression

# %% [markdown]
# xi=[453,11,86]

# %%
xi=[453,11,86]

# %%
w0=7.17
w=[0.01,0.04,0.002]

# %%
def linear_regression(xi):
    pred=w0;
    n = len(xi)
    for j in range(n):
        pred = pred+ xi[j]*w[j]

    return pred

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
np.expm1(12.312)
# Out:
# np.float64(222347.2221101062)

# %%
np.log1p(222347.2221101062)
# Out:
# np.float64(12.312)

# %% [markdown]
# linear regression vector form

# %%
def dot(xi,w):
    n = len(xi)
    res=0.0
    
    for j in range(n):
        res = res+ xi[j]*w[j]
    
    return res

# %%
def linear_regression(xi):
    return w0+dot(xi,w)

# %%
w_new = [w0]+w

# %%
def linear_regression(xi):
    xi = [1] + xi
    return dot(xi,w_new)

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
w0=7.17
w=[0.01,0.04,0.002]
w_new=[w0]+w

# %%
x1=[1,148,24,1385]
x2=[1,132,25,2031]
x10=[1,453,11,86]

X=[x1,x2,x10]
X = np.array(X)
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
def linear_regression(X):
    return X.dot(w_new)

# %%
linear_regression(X)
# Out:
# array([12.38 , 13.552, 12.312])

# %% [markdown]
# Training a linear regression model

# %%
X = [
    [148, 24, 1385],
    [132, 25, 2031],
    [453, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [453, 31, 86],
]


y = [10000, 20000, 15000, 25000, 10000, 20000, 15000, 25000, 12000]


X = np.array(X)
X
# Out:
# array([[ 148,   24, 1385],
#        [ 132,   25, 2031],
#        [ 453,   11,   86],
#        [ 158,   24,  185],
#        [ 172,   25,  201],
#        [ 413,   11,   86],
#        [  38,   54,  185],
#        [ 142,   25,  431],
#        [ 453,   31,   86]])

# %%
ones = np.ones(X.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
X=np.column_stack([ones,X])

# %%
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

# %%
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

XTX.dot(XTX_inv)
# Out:
# array([[ 1.00000000e+00, -1.95495204e-18,  6.28430684e-17,
#          1.75822864e-18],
#        [-9.06380006e-14,  1.00000000e+00,  6.18373354e-15,
#          5.01606559e-17],
#        [-1.90098479e-13,  7.34292862e-18,  1.00000000e+00,
#          2.74699667e-17],
#        [-3.38086980e-13, -7.69365108e-16,  1.45868899e-14,
#          1.00000000e+00]])

# %%
w_full =XTX_inv.dot(X.T).dot(y)

# %%
w_full
# Out:
# array([ 3.00067767e+04, -2.27742529e+01, -2.57694130e+02, -2.30120640e+00])

# %%
w0 = w_full[0]
w= w_full[1:]

# %%
w0,w
# Out:
# (np.float64(30006.77669255554),
#  array([ -22.77425287, -257.69412959,   -2.3012064 ]))

# %%
# def train_linear_regression(X, y):
#     ones = np.ones(X.shape[0])
#     X = np.column_stack([ones, X])

#     XTX = X.T.dot(X)
#     XTX_inv = np.linalg.inv(XTX)
#     w_full = XTX_inv.dot(X.T).dot(y)

#     return w_full[0], w_full[1:]

def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    w_full = np.linalg.pinv(X).dot(y)
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X, y)
# Out:
# (np.float64(15003.388346275771),
#  array([ 1.50033883e+04, -2.27742529e+01, -2.57694130e+02, -2.30120640e+00]))

# %% [markdown]
# CAR BASELINE MODEL

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
base= ['engine_hp','engine_cylinders', 'number_of_doors', 'highway_mpg', 'city_mpg', 'popularity']

df_train[base]
# Out:
#       engine_hp  engine_cylinders  number_of_doors  highway_mpg  city_mpg  \
# 0         148.0               4.0              2.0           33        24
# 1         132.0               4.0              4.0           32        25
# 2         148.0               4.0              4.0           37        28
# 3          90.0               4.0              3.0           18        16
# 4         385.0               8.0              4.0           21        15
# ...         ...               ...              ...          ...       ...
# 7145      300.0               6.0              2.0           31        20
# 7146      210.0               4.0              2.0           30        24
# 7147      285.0               6.0              4.0           22        17
# 7148      563.0              12.0              4.0           21        13
# 7149      200.0               4.0              4.0           31        22
#
#       popularity
# 0           1385
# 1           2031
# 2            640
# ...

# %%
X_train=df_train[base].values
X_train
# Out:
# array([[1.480e+02, 4.000e+00, 2.000e+00, 3.300e+01, 2.400e+01, 1.385e+03],
#        [1.320e+02, 4.000e+00, 4.000e+00, 3.200e+01, 2.500e+01, 2.031e+03],
#        [1.480e+02, 4.000e+00, 4.000e+00, 3.700e+01, 2.800e+01, 6.400e+02],
#        ...,
#        [2.850e+02, 6.000e+00, 4.000e+00, 2.200e+01, 1.700e+01, 5.490e+02],
#        [5.630e+02, 1.200e+01, 4.000e+00, 2.100e+01, 1.300e+01, 8.600e+01],
#        [2.000e+02, 4.000e+00, 4.000e+00, 3.100e+01, 2.200e+01, 8.730e+02]],
#       shape=(7150, 6))

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           40
# engine_cylinders    14
# number_of_doors      6
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
X_train = df_train[base].fillna(0).values
X_train
# Out:
# array([[1.480e+02, 4.000e+00, 2.000e+00, 3.300e+01, 2.400e+01, 1.385e+03],
#        [1.320e+02, 4.000e+00, 4.000e+00, 3.200e+01, 2.500e+01, 2.031e+03],
#        [1.480e+02, 4.000e+00, 4.000e+00, 3.700e+01, 2.800e+01, 6.400e+02],
#        ...,
#        [2.850e+02, 6.000e+00, 4.000e+00, 2.200e+01, 1.700e+01, 5.490e+02],
#        [5.630e+02, 1.200e+01, 4.000e+00, 2.100e+01, 1.300e+01, 8.600e+01],
#        [2.000e+02, 4.000e+00, 4.000e+00, 3.100e+01, 2.200e+01, 8.730e+02]],
#       shape=(7150, 6))

# %%
w0,w = train_linear_regression(X_train, y_train)

# %%
y_pred = X_train.dot(w) + w0

# %%
sns.histplot(y_pred, bins=50)
sns.histplot(y_train, bins=50, color='red')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# RMSE- root mean square error

# %%
def rmse(y,y_pred):
    error= y-y_pred
    se=error**2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train,y_pred)
# Out:
# np.float64(0.737655612196539)

# %% [markdown]
# validating the model

# %%
base= ['engine_hp','engine_cylinders', 'number_of_doors', 'highway_mpg', 'city_mpg', 'popularity']

df_train[base]
X_train = df_train[base].fillna(0).values

w0,w = train_linear_regression(X_train, y_train)
y_pred = X_train.dot(w) + w0

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)

w0,w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val,y_pred)
# Out:
# np.float64(0.745698396230509)

# %% [markdown]
# Simple feature engineering

# %%
2017 -df_train.year
# Out:
# 0        9
# 1        5
# 2        1
# 3       26
# 4        0
#         ..
# 7145     2
# 7146     2
# 7147     2
# 7148     3
# 7149     0
# Name: year, Length: 7150, dtype: int64

# %%
def prepare_X(df):
    df = df.copy()

    df['age'] = 2017 - df.year
    features = base + ['age']

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5168234951483358)

# %%
sns.histplot(y_pred, bins=50)
sns.histplot(y_val, bins=50, color='red')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Categorical variables

# %%
for v in [2,3,4]:
    df_train['num_doors_%s' %v]=(df_train.number_of_doors == v).astype('int')

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
prepare_X(df_train)
# Out:
# array([[148.,   4.,   2., ...,   1.,   0.,   0.],
#        [132.,   4.,   4., ...,   0.,   0.,   1.],
#        [148.,   4.,   4., ...,   0.,   0.,   1.],
#        ...,
#        [285.,   6.,   4., ...,   0.,   0.,   1.],
#        [563.,  12.,   4., ...,   0.,   0.,   1.],
#        [200.,   4.,   4., ...,   0.,   0.,   1.]], shape=(7150, 10))

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5157995641502452)

# %%
makes = list(df.make.value_counts().head().index)

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.507603884955735)

# %%
categorical_variables= [
    'make',
    'engine_fuel_type',
    'transmission_type',
    'driven_wheels',
    'market_category',
    'vehicle_size',
    'vehicle_style'
]

# %%
categories = {}

for c in categorical_variables:
    categories[c] = list(df[c].value_counts().head().index)

# %%
def prepare_X(df):
    df = df.copy()

    df['age'] = 2017 - df['year']
    features = base + ['age']

    for v in [2, 3, 4]:
        df['num_doors_%d' % v] = (df.number_of_doors == v).astype(int)
        features.append('num_doors_%d' % v)

    for name, values in categories.items():
        for value in values:
            df['%s_%s' % (name, value)] = (df[name] == value).astype(int)
            features.append('%s_%s' % (name, value))

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.456517013694551)

# %%
w0,w
# Out:
# (np.float64(6.286648809093639),
#  array([ 1.74593372e-03,  1.10325823e-01, -2.25060293e-01, -5.11418923e-03,
#         -5.92586749e-03, -5.03742753e-05, -9.62111445e-02, -3.40137555e-01,
#         -2.19556532e-01,  2.78471103e-01, -4.23848964e-02,  1.77113119e-01,
#          1.38350936e-02, -9.97691067e-02, -1.07727665e-01, -4.61172642e-01,
#          6.90591028e-02, -3.27355835e-01, -5.40202560e-01, -9.20899158e-02,
#          1.09415308e+00,  9.24610461e-01,  1.15493509e+00,  2.62188423e+00,
#          4.91065955e-01,  1.60772043e+00,  1.53754458e+00,  1.60068184e+00,
#          1.54070197e+00, -8.49948610e-02,  4.57050445e-02, -4.80495451e-02,
#         -3.56610936e-02,  8.60297486e-03,  2.18093536e+00,  2.06578234e+00,
#          2.03993110e+00, -4.85492239e-02,  5.44797374e-02,  1.78241160e-01,
#          3.41906701e-01, -1.64412078e-01]))

# %% [markdown]
# Regularization : we add some small values to the diagonal of our feature matrix so that , inverse always exist , the determinant is not equal to zero(non singular mat)

# %%
def train_linear_regression_reg(X, y, r=0.001):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX = XTX + r * np.eye(XTX.shape[0])

    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)

    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.4565219354864927)

# %%
sns.histplot(y_pred, bins=50)
sns.histplot(y_val, bins=50, color='red')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Fine tuning model

# %%
for r in [0.0, 0.00001, 0.0001, 0.001, 0.1, 1, 10]:
    X_train = prepare_X(df_train)
    w0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

    X_val = prepare_X(df_val)
    y_pred = w0 + X_val.dot(w)

    score = rmse(y_val, y_pred)
    print(r, w0, score)
# Out:
# 0.0 6.27861710311083 0.4565219354864927
# 1e-05 6.27861710311083 0.4565219354864927
# 0.0001 6.27861710311083 0.4565219354864927
# 0.001 6.27861710311083 0.4565219354864927
# 0.1 6.27861710311083 0.4565219354864927
# 1 6.27861710311083 0.4565219354864927
# 10 6.27861710311083 0.4565219354864927

# %% [markdown]
# for us the score is same , because we have used pinv() in train_linear_regression,
# Pseudo-inverse ensures numerical stability when the feature matrix is singular, while regularization modifies the optimization objective by penalizing large weights. The improvement in RMSE comes from better generalization due to regularization, not merely from the existence of an inverse.

# %% [markdown]
# using the model

# %%
df_full_train = pd.concat([df_train,df_val])

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train
# Out:
#             make                    model  year             engine_fuel_type  \
# 0      chevrolet                   cobalt  2008             regular_unleaded
# 1         toyota                   matrix  2012             regular_unleaded
# 2         subaru                  impreza  2016             regular_unleaded
# 3     volkswagen                  vanagon  1991             regular_unleaded
# 4           ford                    f-150  2017     flex-fuel_(unleaded/e85)
# ...          ...                      ...   ...                          ...
# 9527       volvo                      v60  2015             regular_unleaded
# 9528    maserati  granturismo_convertible  2015  premium_unleaded_(required)
# 9529    cadillac          escalade_hybrid  2013             regular_unleaded
# 9530  mitsubishi                   lancer  2016             regular_unleaded
# 9531         kia                  sorento  2015             regular_unleaded
#
# ...

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[148.,   4.,   2., ...,   1.,   0.,   0.],
#        [132.,   4.,   4., ...,   0.,   0.,   1.],
#        [148.,   4.,   4., ...,   0.,   0.,   1.],
#        ...,
#        [332.,   8.,   4., ...,   0.,   0.,   0.],
#        [148.,   4.,   4., ...,   0.,   0.,   0.],
#        [290.,   6.,   4., ...,   0.,   0.,   0.]], shape=(9532, 42))

# %%
y_full_train = np.concatenate([y_train,y_val])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train, r=0.001)

# %%
w
# Out:
# array([ 1.52507277e-03,  1.18188553e-01, -2.26720808e-01, -6.66125048e-03,
#        -5.33384965e-03, -4.87602655e-05, -9.69091204e-02, -3.39555937e-01,
#        -2.11078407e-01,  2.71406732e-01, -4.14333520e-02,  1.75561122e-01,
#        -5.77652097e-04, -1.00564269e-01, -9.27545856e-02, -4.66858622e-01,
#         7.98664395e-02, -3.16046808e-01, -5.51980417e-01, -7.89508509e-02,
#         1.09563505e+00,  9.20327144e-01,  1.14990382e+00,  2.65299555e+00,
#         5.10264499e-01,  1.62954944e+00,  1.53025355e+00,  1.61743094e+00,
#         1.54543132e+00, -9.70553883e-02,  3.73063382e-02, -5.81760498e-02,
#        -2.35932912e-02, -1.19342568e-02,  2.18902099e+00,  2.07465104e+00,
#         2.05923378e+00, -5.00811674e-02,  5.62178271e-02,  1.84793527e-01,
#         3.32646034e-01, -1.58816822e-01])

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test, y_pred)
score
# Out:
# np.float64(0.45177498956243806)

# %%
car = df_test.iloc[20].to_dict()
car
# Out:
# {'make': 'toyota',
#  'model': 'sienna',
#  'year': 2015,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 266.0,
#  'engine_cylinders': 6.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 4.0,
#  'market_category': nan,
#  'vehicle_size': 'large',
#  'vehicle_style': 'passenger_minivan',
#  'highway_mpg': 25,
#  'city_mpg': 18,
#  'popularity': 2031}

# %%
df_small = pd.DataFrame([car])

# %%
df_small
# Out:
#      make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  toyota  sienna  2015  regular_unleaded      266.0               6.0
#
#   transmission_type      driven_wheels  number_of_doors  market_category  \
# 0         automatic  front_wheel_drive              4.0              NaN
#
#   vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity
# 0        large  passenger_minivan           25        18        2031

# %%
X_small = prepare_X(df_small)

# %%
y_pred = w0 + X_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# np.float64(10.46265062303032)

# %% [markdown]
# our model predicted price is below

# %%
np.expm1(y_pred)
# Out:
# np.float64(34983.15847569468)

# %% [markdown]
# //exact value of such car is below

# %%
np.expm1(y_test[20])
# Out:
# np.float64(35000.00000000001)
